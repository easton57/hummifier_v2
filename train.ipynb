# %%
# Need to run these from your terminal
# Create python environment
# !python -m venv venv
# install jupyter notebook
# !pip install jupyter

# %%
import os
import wget

# %% [markdown]
# # Function for creating the necessary paths

# %%
def create_paths(custom_model_name):
    """ Method to create the needed paths """
    tf_record_script = 'generate_tfrecord.py'
    label_map = 'label_map.pbtxt'

    # Setting up Folder Structure
    paths = {
        'tensorflow_path': os.path.join('Tensorflow'),
        'workspace_path': os.path.join('Tensorflow', 'workspace'),
        'scripts_path': os.path.join('Tensorflow', 'scripts'),
        'api_path': os.path.join('Tensorflow', 'models'),
        'annotation_path': os.path.join('Tensorflow', 'workspace', 'annotations'),
        'image_path': os.path.join('Tensorflow', 'workspace', 'images'),
        'train_image_path': os.path.join('Tensorflow', 'workspace', 'images', 'train'),
        'test_image_path': os.path.join('Tensorflow', 'workspace', 'images', 'test'),
        'model_path': os.path.join('Tensorflow', 'workspace', 'models'),
        'pretrained_model_path': os.path.join('Tensorflow', 'workspace', 'pre-trained-models'),
        'checkpoint_path': os.path.join('Tensorflow', 'workspace', 'models', custom_model_name),
        'output_path': os.path.join('Tensorflow', 'workspace', 'models', custom_model_name, 'export'),
        'protoc_path': os.path.join('Tensorflow', 'protoc')
    }

    files = {
        'pipeline_config': os.path.join('Tensorflow', 'workspace', 'models', custom_model_name, 'pipeline.config'),
        'tf_record_script': os.path.join(paths['scripts_path'], tf_record_script),
        'labelmap': os.path.join(paths['annotation_path'], label_map)
    }

    # Create Folder Structure
    for path in paths.values():
        if not os.path.exists(path):
            os.mkdir(path)

    return paths, files

# %% [markdown]
# # Function for downloading needed files

# %%
def download_files(paths):
    if linux:
        protobuff = "https://github.com/protocolbuffers/protobuf/releases/download/v25.3/protoc-25.3-linux-x86_64.zip"
        zip = "protoc-25.3-linux-x86_64.zip"
    elif mac:
        protobuff = "https://github.com/protocolbuffers/protobuf/releases/download/v26.0-rc3/protoc-26.0-rc-3-osx-universal_binary.zip"
        zip = "protoc-26.0-rc-3-osx-universal_binary.zip"
    else:
        protobuff = "https://github.com/protocolbuffers/protobuf/releases/download/v25.3/protoc-25.3-win64.zip"
        zip = "protoc-25.3-win64.zip"
    
    # urls
    download_urls = {
        'protobuff': protobuff,
        'tensorflow_models': "https://github.com/tensorflow/models/archive/refs/heads/master.zip",
        'pretrained_model': "http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz"
    }
    
    pretrained_model = 'ssd_mobilenet_v2_320x320_coco17_tpu-8'

    # Download files
    wget.download(download_urls["protobuff"], paths['protoc_path'])
    wget.download(download_urls["tensorflow_models"], paths['api_path'])
    wget.download(download_urls["pretrained_model"], paths['pretrained_model_path'])

    # Extract Files
    if linux or mac:
        # !cd {paths['protoc_path']} && unzip {zip}
        # !cd {paths['api_path']} && unzip models-master.zip -d ./tmp && mv ./tmp/*/* .
    else:
        # !cd {paths['protoc_path']} && tar -xf {zip}
        # !cd {paths['api_path']} && tar -xf models-master.zip --strip-components 1
        
    # !cd {paths['pretrained_model_path']} && tar -zxvf {pretrained_model + '.tar.gz'}

    # add protoc to path
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['protoc_path'], 'bin'))

# %% [markdown]
# # Function for verifying environment

# %%
def verify_install(paths, setup=False):
    if setup:
        if linux or mac:
            # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py setup.py && python setup.py build && python setup.py install
        else:
            # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
        # !cd Tensorflow/models/research/slim && pip install -e .

    verification_script = os.path.join(paths['api_path'], 'research', 'object_detection', 'builders',
                                       'model_builder_tf2_test.py')
    # !python {verification_script}

# %% [markdown]
# # Environment Setup
# Please note, lines starting with ! will have to be run from a command line or adapted to run in a python file

# %%
# Change to false if you are on windows
linux=False
mac=True

# %%
# Create the paths and get the file and path dictionaries
paths, files = create_paths('hummifier_model')

# %%
# Get our execution dependencies
download_files(paths)
# Out:
# Archive:  protoc-26.0-rc-3-osx-universal_binary.zip
# replace include/google/protobuf/struct.proto? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
# Archive:  models-master.zip
# 0429a9339527cfc699ae9bea0093879538e94874
# replace ./tmp/models-master/.github/ISSUE_TEMPLATE/00-official-bug-report-issue.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
# Verify installation
# The final outcome should be similar to 24 tests ran
verify_install(paths, setup=True)
# Out:
# running build
# running build_py
# copying object_detection/protos/pipeline_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/string_int_label_map_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/keypoint_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/train_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/square_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/argmax_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/region_similarity_calculator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_predictor_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/faster_rcnn_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/center_net_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/bipartite_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/image_resizer_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/calibration_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/target_assigner_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/ssd_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/preprocessor_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/eval_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/graph_rewriter_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/flexible_grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/faster_rcnn_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/mean_stddev_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/model_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/optimizer_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/hyperparams_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/losses_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/fpn_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/input_reader_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/multiscale_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/post_processing_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/ssd_pb2.py -> build/lib/object_detection/protos
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# reading manifest file 'object_detection.egg-info/SOURCES.txt'
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# running install
# /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# reading manifest file 'object_detection.egg-info/SOURCES.txt'
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.1-arm64/egg
# running install_lib
# running build_py
# creating build/bdist.macosx-11.1-arm64/egg
# creating build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/download_and_convert_visualwakewords_lib.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/preprocess_imagenet_validation_data.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/imagenet.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/__init__.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/dataset_utils.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/build_imagenet_data.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/process_bounding_boxes.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/dataset_factory.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/cifar10.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/download_and_convert_cifar10.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/visualwakewords.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/download_and_convert_flowers.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/download_and_convert_visualwakewords.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/download_and_convert_mnist.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/flowers.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# copying build/lib/datasets/mnist.py -> build/bdist.macosx-11.1-arm64/egg/datasets
# creating build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/resnet_v2_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/overfeat_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# creating build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/mobilenet_v2.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/__init__.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/mobilenet_v3.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/mobilenet.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/mobilenet_v2_test.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/conv_blocks.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/mobilenet/mobilenet_v3_test.py -> build/bdist.macosx-11.1-arm64/egg/nets/mobilenet
# copying build/lib/nets/resnet_v1.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_resnet_v2.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v4_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/vgg.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/mobilenet_v1_eval.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/post_training_quantization.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v1.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_resnet_v2_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/vgg_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/resnet_v1_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/s3dg.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/nets_factory.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/i3d_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/__init__.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v4.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/resnet_utils.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/s3dg_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/alexnet_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/mobilenet_v1_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v3_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/cyclegan_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/pix2pix_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/lenet.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/dcgan.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v3.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v2.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_utils.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/i3d.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/inception_v2_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/mobilenet_v1.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/dcgan_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/nets_factory_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/cifarnet.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/i3d_utils.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/overfeat.py -> build/bdist.macosx-11.1-arm64/egg/nets
# creating build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/nasnet_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/__init__.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/pnasnet.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/nasnet_test.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/pnasnet_test.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/nasnet.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/nasnet/nasnet_utils.py -> build/bdist.macosx-11.1-arm64/egg/nets/nasnet
# copying build/lib/nets/inception_v1_test.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/alexnet.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/resnet_v2.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/pix2pix.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/mobilenet_v1_train.py -> build/bdist.macosx-11.1-arm64/egg/nets
# copying build/lib/nets/cyclegan.py -> build/bdist.macosx-11.1-arm64/egg/nets
# creating build/bdist.macosx-11.1-arm64/egg/deployment
# copying build/lib/deployment/model_deploy.py -> build/bdist.macosx-11.1-arm64/egg/deployment
# copying build/lib/deployment/__init__.py -> build/bdist.macosx-11.1-arm64/egg/deployment
# copying build/lib/deployment/model_deploy_test.py -> build/bdist.macosx-11.1-arm64/egg/deployment
# creating build/bdist.macosx-11.1-arm64/egg/object_detection
# copying build/lib/object_detection/exporter_lib_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_metrics_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_tools.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_tools_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_vrd_challenge_evaluation_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_vrd_challenge_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/tf_example_parser_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/offline_eval_map_corloc_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_evaluation_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/tf_example_parser.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_challenge_evaluation_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_vrd_challenge_evaluation_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_tools_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/offline_eval_map_corloc.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_evaluation_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/io_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_challenge_evaluation_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/lvis_tools.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/coco_evaluation_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/calibration_metrics.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# copying build/lib/object_detection/metrics/oid_challenge_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/metrics
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/faster_rcnn_meta_arch.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_meta_arch_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/rfcn_meta_arch_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_meta_arch.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/ssd_meta_arch_test_lib.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/center_net_meta_arch.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/deepmac_meta_arch_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/faster_rcnn_meta_arch_test_lib.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/deepmac_meta_arch.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/ssd_meta_arch_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib_tf2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/faster_rcnn_meta_arch_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/context_rcnn_lib_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/rfcn_meta_arch.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/center_net_meta_arch_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# copying build/lib/object_detection/meta_architectures/ssd_meta_arch.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/meta_architectures
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters/testdata
# copying build/lib/object_detection/tpu_exporters/testdata/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters/testdata
# copying build/lib/object_detection/tpu_exporters/utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/ssd.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/export_saved_model_tpu_lib_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/faster_rcnn.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/export_saved_model_tpu.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/tpu_exporters/export_saved_model_tpu_lib.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/tpu_exporters
# copying build/lib/object_detection/export_tflite_ssd_graph_lib.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/pipeline_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/string_int_label_map_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/keypoint_box_coder_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/train_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/square_box_coder_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/argmax_matcher_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/region_similarity_calculator_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/box_predictor_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/faster_rcnn_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/grid_anchor_generator_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/matcher_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/center_net_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/bipartite_matcher_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/image_resizer_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/calibration_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/target_assigner_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/ssd_anchor_generator_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/preprocessor_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/eval_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/graph_rewriter_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/flexible_grid_anchor_generator_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/faster_rcnn_box_coder_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/mean_stddev_box_coder_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/anchor_generator_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/box_coder_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/model_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/optimizer_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/hyperparams_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/losses_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/fpn_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/input_reader_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/multiscale_anchor_generator_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/post_processing_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# copying build/lib/object_detection/protos/ssd_pb2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/protos
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/target_assigner.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/batcher_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/model_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/prefetcher_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/data_decoder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/matcher.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/balanced_positive_negative_sampler_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/preprocessor_cache.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/batch_multiclass_nms_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_coder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/standard_fields.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/minibatch_sampler.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/preprocessor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/data_parser.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/prefetcher.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/model.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/anchor_generator.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/minibatch_sampler_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/preprocessor_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/densepose_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/keypoint_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/balanced_positive_negative_sampler.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/freezable_batch_norm.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/target_assigner_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/freezable_sync_batch_norm.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_list.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/post_processing.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/losses.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/freezable_batch_norm_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/region_similarity_calculator.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/box_coder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/class_agnostic_nms_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/densepose_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/losses_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/keypoint_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/region_similarity_calculator_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/batcher.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/multiclass_nms_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/core/matcher_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/core
# copying build/lib/object_detection/exporter_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# copying build/lib/object_detection/model_lib.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/optimizer_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/input_reader_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/graph_rewriter_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_predictor_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/optimizer_builder_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/matcher_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_coder_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/preprocessor_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/input_reader_builder_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/post_processing_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/dataset_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/matcher_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/preprocessor_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/region_similarity_calculator_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/post_processing_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/calibration_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/decoder_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/hyperparams_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/optimizer_builder_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/graph_rewriter_builder_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/dataset_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/image_resizer_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/anchor_generator_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/anchor_generator_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_predictor_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/region_similarity_calculator_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/decoder_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/image_resizer_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/target_assigner_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/hyperparams_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/losses_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/losses_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/calibration_builder_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/model_builder_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_coder_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/builders/target_assigner_builder.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/builders
# copying build/lib/object_detection/exporter.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# copying build/lib/object_detection/exporter_lib_v2.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# copying build/lib/object_detection/export_tflite_graph_lib_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/trainer_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/train.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/trainer.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/eval.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/legacy/evaluator.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/legacy
# copying build/lib/object_detection/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/mask_rcnn_box_predictor_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/rfcn_box_predictor_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/mask_rcnn_box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/mask_rcnn_keras_box_predictor_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/convolutional_box_predictor_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/rfcn_keras_box_predictor_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/rfcn_box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keras_class_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/mask_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/box_head_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keras_class_head_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keras_box_head_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/mask_head_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/box_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keras_mask_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keypoint_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keras_mask_head_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keras_box_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/class_head_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/keypoint_head_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/heads/class_head.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors/heads
# copying build/lib/object_detection/predictors/mask_rcnn_keras_box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/rfcn_keras_box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/convolutional_keras_box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/convolutional_keras_box_predictor_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# copying build/lib/object_detection/predictors/convolutional_box_predictor.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/predictors
# creating build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/visualization_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/autoaugment_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/label_map_util_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/tf_version.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/metrics.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/test_case_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_mask_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/test_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_list_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/learning_schedules.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/context_manager.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_list_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/bifpn_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/spatial_transform_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/learning_schedules_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_mask_list_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/per_image_evaluation_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/model_util.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/variables_helper.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/model_util_tf2_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/category_util_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_list_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/config_util_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_list.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/patch_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/object_detection_evaluation_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/dataset_util_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/shape_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_mask_list.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/static_shape_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/__init__.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/metrics_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/json_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/per_image_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_mask_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/test_case.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/patch_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/label_map_util.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/spatial_transform_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_mask_list_ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/variables_helper_tf1_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/per_image_vrd_evaluation_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/np_box_mask_list_ops.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/dataset_util.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/ops_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/visualization_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/per_image_vrd_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/object_detection_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/target_assigner_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/json_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/static_shape.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/context_manager_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/config_util.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/category_util.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/vrd_evaluation_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/vrd_evaluation.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/test_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/colab_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/shape_utils_test.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# copying build/lib/object_detection/utils/target_assigner_utils.py -> build/bdist.macosx-11.1-arm64/egg/object_detection/utils
# ...
# I0308 14:17:30.546141 8088866816 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0308 14:17:30.583616 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0308 14:17:30.583717 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 288
# I0308 14:17:30.583747 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I0308 14:17:30.584771 8088866816 efficientnet_model.py:143] round_filter input=32 output=48
# I0308 14:17:30.590548 8088866816 efficientnet_model.py:143] round_filter input=32 output=48
# I0308 14:17:30.590600 8088866816 efficientnet_model.py:143] round_filter input=16 output=24
# I0308 14:17:30.657433 8088866816 efficientnet_model.py:143] round_filter input=16 output=24
# I0308 14:17:30.657530 8088866816 efficientnet_model.py:143] round_filter input=24 output=40
# I0308 14:17:30.904428 8088866816 efficientnet_model.py:143] round_filter input=24 output=40
# I0308 14:17:30.904515 8088866816 efficientnet_model.py:143] round_filter input=40 output=64
# I0308 14:17:31.066762 8088866816 efficientnet_model.py:143] round_filter input=40 output=64
# I0308 14:17:31.066848 8088866816 efficientnet_model.py:143] round_filter input=80 output=128
# I0308 14:17:31.308960 8088866816 efficientnet_model.py:143] round_filter input=80 output=128
# I0308 14:17:31.309040 8088866816 efficientnet_model.py:143] round_filter input=112 output=176
# I0308 14:17:31.549103 8088866816 efficientnet_model.py:143] round_filter input=112 output=176
# I0308 14:17:31.549189 8088866816 efficientnet_model.py:143] round_filter input=192 output=304
# I0308 14:17:31.892964 8088866816 efficientnet_model.py:143] round_filter input=192 output=304
# I0308 14:17:31.893052 8088866816 efficientnet_model.py:143] round_filter input=320 output=512
# I0308 14:17:32.030745 8088866816 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0308 14:17:32.054427 8088866816 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0308 14:17:32.100262 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0308 14:17:32.100360 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0308 14:17:32.100386 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0308 14:17:32.101362 8088866816 efficientnet_model.py:143] round_filter input=32 output=56
# I0308 14:17:32.108947 8088866816 efficientnet_model.py:143] round_filter input=32 output=56
# I0308 14:17:32.109035 8088866816 efficientnet_model.py:143] round_filter input=16 output=32
# I0308 14:17:32.180229 8088866816 efficientnet_model.py:143] round_filter input=16 output=32
# I0308 14:17:32.180319 8088866816 efficientnet_model.py:143] round_filter input=24 output=40
# I0308 14:17:32.351142 8088866816 efficientnet_model.py:143] round_filter input=24 output=40
# I0308 14:17:32.351219 8088866816 efficientnet_model.py:143] round_filter input=40 output=72
# I0308 14:17:32.535906 8088866816 efficientnet_model.py:143] round_filter input=40 output=72
# I0308 14:17:32.535984 8088866816 efficientnet_model.py:143] round_filter input=80 output=144
# I0308 14:17:32.783685 8088866816 efficientnet_model.py:143] round_filter input=80 output=144
# I0308 14:17:32.783775 8088866816 efficientnet_model.py:143] round_filter input=112 output=200
# I0308 14:17:33.042970 8088866816 efficientnet_model.py:143] round_filter input=112 output=200
# I0308 14:17:33.043051 8088866816 efficientnet_model.py:143] round_filter input=192 output=344
# I0308 14:17:33.536153 8088866816 efficientnet_model.py:143] round_filter input=192 output=344
# I0308 14:17:33.536256 8088866816 efficientnet_model.py:143] round_filter input=320 output=576
# I0308 14:17:33.683780 8088866816 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0308 14:17:33.708905 8088866816 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0308 14:17:33.757987 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0308 14:17:33.758066 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0308 14:17:33.758091 8088866816 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0308 14:17:33.758941 8088866816 efficientnet_model.py:143] round_filter input=32 output=64
# I0308 14:17:33.765988 8088866816 efficientnet_model.py:143] round_filter input=32 output=64
# I0308 14:17:33.766072 8088866816 efficientnet_model.py:143] round_filter input=16 output=32
# I0308 14:17:33.860903 8088866816 efficientnet_model.py:143] round_filter input=16 output=32
# I0308 14:17:33.860984 8088866816 efficientnet_model.py:143] round_filter input=24 output=48
# I0308 14:17:34.068153 8088866816 efficientnet_model.py:143] round_filter input=24 output=48
# I0308 14:17:34.068234 8088866816 efficientnet_model.py:143] round_filter input=40 output=80
# I0308 14:17:34.277827 8088866816 efficientnet_model.py:143] round_filter input=40 output=80
# I0308 14:17:34.277908 8088866816 efficientnet_model.py:143] round_filter input=80 output=160
# I0308 14:17:34.594996 8088866816 efficientnet_model.py:143] round_filter input=80 output=160
# I0308 14:17:34.595093 8088866816 efficientnet_model.py:143] round_filter input=112 output=224
# I0308 14:17:34.924576 8088866816 efficientnet_model.py:143] round_filter input=112 output=224
# I0308 14:17:34.924657 8088866816 efficientnet_model.py:143] round_filter input=192 output=384
# I0308 14:17:35.409600 8088866816 efficientnet_model.py:143] round_filter input=192 output=384
# I0308 14:17:35.409683 8088866816 efficientnet_model.py:143] round_filter input=320 output=640
# I0308 14:17:35.618356 8088866816 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0308 14:17:35.644241 8088866816 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 9.35s
# I0308 14:17:35.706038 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 9.35s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0308 14:17:35.715175 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0308 14:17:35.715925 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0308 14:17:35.716090 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0308 14:17:35.716645 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0308 14:17:35.717164 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0308 14:17:35.717289 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0308 14:17:35.717685 8088866816 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 11.191s
#
# OK (skipped=1)

# %% [markdown]
# If you get error: module 'keras._tf_keras.keras.layers' has no attribute 'experimental'
#
# reinstall tensorflow with: pip install tensorflow=2.13.0

# %% [markdown]
# # Data preparation

# %%
# run this and label your images as needed
# !labelImg
# Out:
# QSocketNotifier: Can only be used with threads started with QThread

# %%
# Create a pbtext file with each of your labels like below. The labels should match what you used in labelImg
"""
item {
    id: 1
    name: "archilochus alexandri"
}
"""
# Out:
# '\nitem {\n    id: 1\n    name: "archilochus alexandri"\n}\n'

# %%
# Create record files for training and testing datasets
# !python {files['tf_record_script']} -x {os.path.join(paths['image_path'], 'train')} -l {files['labelmap']} -o {os.path.join(paths['annotation_path'], 'train.record')} 
# !python {files['tf_record_script']} -x {os.path.join(paths['image_path'], 'test')} -l {files['labelmap']} -o {os.path.join(paths['annotation_path'], 'test.record')}
# Out:
# 2024-03-06 20:32:53.026409: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-06 20:32:53.026447: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-06 20:32:53.027695: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-06 20:32:54.496448: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# 2024-03-06 20:32:56.304421: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-06 20:32:56.304460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-06 20:32:56.305677: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-06 20:32:57.798373: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # Configure Model

# %%
# Copy the pipeline config from the existing model
if linux or mac:
    # !cp {os.path.join(paths['pretrained_model_path'], pretrained_model, 'pipeline.config')} {os.path.join(paths['checkpoint_path'])}
else:
    # !copy {os.path.join(paths['pretrained_model_path'], pretrained_model, 'pipeline.config')} {os.path.join(paths['checkpoint_path'])}

"""
After the copy is done, open the file in a text editor and change the following

num_classes: Set to the number of label classes you have in your pbtxt file
batch_size: increase or decrease based on what batch size you want to use for training
total_steps, num_steps: change based on the data that's available and the accuracy you're achieving
fine_tune_checkpoint: path to the check point of the pre-trained model
fine_tune_checkpoint_type: set to detection
label_map_path: path to your pbtxt file
input_path: path to train and test .record files
"""
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `cp {os.path.join(paths['pretrained_model_path'], pretrained_model, 'pipeline.config')} {os.path.join(paths['checkpoint_path'])}'
# "\nAfter the copy is done, open the file in a text editor and change the following\n\nnum_classes: Set to the number of label classes you have in your pbtxt file\nbatch_size: increase or decrease based on what batch size you want to use for training\ntotal_steps, num_steps: change based on the data that's available and the accuracy you're achieving\nfine_tune_checkpoint: path to the check point of the pre-trained model\nlabel_map_path: path to your pbtxt file\ninput_path: path to train and test .record files\n"

# %% [markdown]
# # Train the model

# %%
training_script = os.path.join(paths['api_path'], 'research', 'object_detection', 'model_main_tf2.py')
training_command = "python {} --model_dir={} --pipeline_config_path={}".format(training_script, paths['checkpoint_path'], files['pipeline_config'])
tensorboard_command = "tensorboard --logdir={}".format(paths['checkpoint_path'])

print(training_script)
print("Run the following in a new terminal: " + training_command)
print("To view training progress, run the following in a second terminal: " + tensorboard_command)
# Out:
# Tensorflow/models/research/object_detection/model_main_tf2.py
# Run the following in a new terminal: python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/hummifier_model --pipeline_config_path=Tensorflow/workspace/models/hummifier_model/pipeline.config
# To view training progress, run the following in a second terminal: tensorboard --logdir=Tensorflow/workspace/models/hummifier_model

# %%
# !{training_command}
# Out:
# 2024-03-07 10:41:03.667406: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2024-03-07 10:41:03.667432: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-03-07 10:41:03.667437: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-03-07 10:41:03.667494: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-07 10:41:03.667517: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0307 10:41:03.668721 8088866816 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0307 10:41:03.679362 8088866816 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0307 10:41:03.679453 8088866816 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0307 10:41:03.697932 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0307 10:41:03.701587 8088866816 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0307 10:41:03.701760 8088866816 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0307 10:41:03.701797 8088866816 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0307 10:41:03.701817 8088866816 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0307 10:41:03.705436 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0307 10:41:03.713999 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0307 10:41:07.709214 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0307 10:41:09.132690 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0307 10:41:10.296391 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2024-03-07 10:41:11.479479: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-03-07 10:41:11.483014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0307 10:41:16.622118 11827900416 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 10:41:17.322376 11827900416 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 10:41:17.322532 11827900416 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 10:41:17.322582 11827900416 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 10:41:17.322619 11827900416 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 10:41:17.322651 11827900416 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 10:41:17.322682 11827900416 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# I0307 10:41:21.477635 12104790016 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# 2024-03-07 10:41:24.082570: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-03-07 10:41:31.339154: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-03-07 10:41:31.343181: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.395935 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.398667 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.399780 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.401167 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.404003 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.405219 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.406207 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.407447 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.410707 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 10:41:31.411590 8088866816 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0307 10:41:32.336552 18396246016 deprecation.py:569] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0307 10:41:32.725445 18396246016 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0307 10:41:36.590228 12901707776 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0307 10:41:41.743315 14459891712 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0307 10:41:45.273753 14940139520 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# 2024-03-07 10:41:48.573042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Step 100 per-step time 1.360s
# I0307 10:43:48.198653 8088866816 model_lib_v2.py:705] Step 100 per-step time 1.360s
# INFO:tensorflow:{'Loss/classification_loss': 0.49261156,
#  'Loss/localization_loss': 0.18694443,
#  'Loss/regularization_loss': 0.0984985,
#  'Loss/total_loss': 0.77805454,
#  'learning_rate': 0.1666635}
# I0307 10:43:48.199803 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.49261156,
#  'Loss/localization_loss': 0.18694443,
#  'Loss/regularization_loss': 0.0984985,
#  'Loss/total_loss': 0.77805454,
#  'learning_rate': 0.1666635}
# INFO:tensorflow:Step 200 per-step time 0.848s
# I0307 10:45:12.983047 8088866816 model_lib_v2.py:705] Step 200 per-step time 0.848s
# INFO:tensorflow:{'Loss/classification_loss': 0.33878255,
#  'Loss/localization_loss': 0.13883997,
#  'Loss/regularization_loss': 0.10275002,
#  'Loss/total_loss': 0.5803725,
#  'learning_rate': 0.19999701}
# I0307 10:45:12.983762 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.33878255,
#  'Loss/localization_loss': 0.13883997,
#  'Loss/regularization_loss': 0.10275002,
#  'Loss/total_loss': 0.5803725,
#  'learning_rate': 0.19999701}
# INFO:tensorflow:Step 300 per-step time 0.844s
# I0307 10:46:37.346386 8088866816 model_lib_v2.py:705] Step 300 per-step time 0.844s
# INFO:tensorflow:{'Loss/classification_loss': 0.4351289,
#  'Loss/localization_loss': 0.19665143,
#  'Loss/regularization_loss': 0.106843285,
#  'Loss/total_loss': 0.7386236,
#  'learning_rate': 0.23333052}
# I0307 10:46:37.347107 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.4351289,
#  'Loss/localization_loss': 0.19665143,
#  'Loss/regularization_loss': 0.106843285,
#  'Loss/total_loss': 0.7386236,
#  'learning_rate': 0.23333052}
# INFO:tensorflow:Step 400 per-step time 0.940s
# I0307 10:48:11.337141 8088866816 model_lib_v2.py:705] Step 400 per-step time 0.940s
# INFO:tensorflow:{'Loss/classification_loss': 0.35780942,
#  'Loss/localization_loss': 0.13111155,
#  'Loss/regularization_loss': 0.11298104,
#  'Loss/total_loss': 0.601902,
#  'learning_rate': 0.26666403}
# I0307 10:48:11.337838 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.35780942,
#  'Loss/localization_loss': 0.13111155,
#  'Loss/regularization_loss': 0.11298104,
#  'Loss/total_loss': 0.601902,
#  'learning_rate': 0.26666403}
# INFO:tensorflow:Step 500 per-step time 1.001s
# I0307 10:49:51.481111 8088866816 model_lib_v2.py:705] Step 500 per-step time 1.001s
# INFO:tensorflow:{'Loss/classification_loss': 0.4898576,
#  'Loss/localization_loss': 0.19329765,
#  'Loss/regularization_loss': 0.1189181,
#  'Loss/total_loss': 0.8020734,
#  'learning_rate': 0.2999975}
# I0307 10:49:51.481767 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.4898576,
#  'Loss/localization_loss': 0.19329765,
#  'Loss/regularization_loss': 0.1189181,
#  'Loss/total_loss': 0.8020734,
#  'learning_rate': 0.2999975}
# INFO:tensorflow:Step 600 per-step time 0.897s
# I0307 10:51:21.181663 8088866816 model_lib_v2.py:705] Step 600 per-step time 0.897s
# INFO:tensorflow:{'Loss/classification_loss': 0.20394221,
#  'Loss/localization_loss': 0.08367831,
#  'Loss/regularization_loss': 0.12399486,
#  'Loss/total_loss': 0.41161537,
#  'learning_rate': 0.33333102}
# I0307 10:51:21.182333 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.20394221,
#  'Loss/localization_loss': 0.08367831,
#  'Loss/regularization_loss': 0.12399486,
#  'Loss/total_loss': 0.41161537,
#  'learning_rate': 0.33333102}
# INFO:tensorflow:Step 700 per-step time 0.956s
# I0307 10:52:56.742146 8088866816 model_lib_v2.py:705] Step 700 per-step time 0.956s
# INFO:tensorflow:{'Loss/classification_loss': 0.36282617,
#  'Loss/localization_loss': 0.13993983,
#  'Loss/regularization_loss': 0.13146564,
#  'Loss/total_loss': 0.6342317,
#  'learning_rate': 0.36666453}
# I0307 10:52:56.742933 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.36282617,
#  'Loss/localization_loss': 0.13993983,
#  'Loss/regularization_loss': 0.13146564,
#  'Loss/total_loss': 0.6342317,
#  'learning_rate': 0.36666453}
# INFO:tensorflow:Step 800 per-step time 0.905s
# I0307 10:54:27.199291 8088866816 model_lib_v2.py:705] Step 800 per-step time 0.905s
# INFO:tensorflow:{'Loss/classification_loss': 0.17092931,
#  'Loss/localization_loss': 0.07787283,
#  'Loss/regularization_loss': 0.15078704,
#  'Loss/total_loss': 0.39958918,
#  'learning_rate': 0.399998}
# I0307 10:54:27.199996 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.17092931,
#  'Loss/localization_loss': 0.07787283,
#  'Loss/regularization_loss': 0.15078704,
#  'Loss/total_loss': 0.39958918,
#  'learning_rate': 0.399998}
# INFO:tensorflow:Step 900 per-step time 0.943s
# I0307 10:56:01.450894 8088866816 model_lib_v2.py:705] Step 900 per-step time 0.943s
# INFO:tensorflow:{'Loss/classification_loss': 0.24219151,
#  'Loss/localization_loss': 0.109923735,
#  'Loss/regularization_loss': 0.16050267,
#  'Loss/total_loss': 0.51261795,
#  'learning_rate': 0.4333315}
# I0307 10:56:01.451563 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.24219151,
#  'Loss/localization_loss': 0.109923735,
#  'Loss/regularization_loss': 0.16050267,
#  'Loss/total_loss': 0.51261795,
#  'learning_rate': 0.4333315}
# INFO:tensorflow:Step 1000 per-step time 0.912s
# I0307 10:57:32.686629 8088866816 model_lib_v2.py:705] Step 1000 per-step time 0.912s
# INFO:tensorflow:{'Loss/classification_loss': 0.3340984,
#  'Loss/localization_loss': 0.14526261,
#  'Loss/regularization_loss': 0.16708812,
#  'Loss/total_loss': 0.6464491,
#  'learning_rate': 0.46666503}
# I0307 10:57:32.687315 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.3340984,
#  'Loss/localization_loss': 0.14526261,
#  'Loss/regularization_loss': 0.16708812,
#  'Loss/total_loss': 0.6464491,
#  'learning_rate': 0.46666503}
# INFO:tensorflow:Step 1100 per-step time 0.983s
# I0307 10:59:10.963952 8088866816 model_lib_v2.py:705] Step 1100 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.120620884,
#  'Loss/localization_loss': 0.099723,
#  'Loss/regularization_loss': 0.17392598,
#  'Loss/total_loss': 0.39426988,
#  'learning_rate': 0.4999985}
# I0307 10:59:10.964795 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.120620884,
#  'Loss/localization_loss': 0.099723,
#  'Loss/regularization_loss': 0.17392598,
#  'Loss/total_loss': 0.39426988,
#  'learning_rate': 0.4999985}
# INFO:tensorflow:Step 1200 per-step time 0.952s
# I0307 11:00:46.201834 8088866816 model_lib_v2.py:705] Step 1200 per-step time 0.952s
# INFO:tensorflow:{'Loss/classification_loss': 0.24771516,
#  'Loss/localization_loss': 0.10128399,
#  'Loss/regularization_loss': 0.18657734,
#  'Loss/total_loss': 0.53557646,
#  'learning_rate': 0.53333205}
# I0307 11:00:46.202507 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.24771516,
#  'Loss/localization_loss': 0.10128399,
#  'Loss/regularization_loss': 0.18657734,
#  'Loss/total_loss': 0.53557646,
#  'learning_rate': 0.53333205}
# INFO:tensorflow:Step 1300 per-step time 0.950s
# I0307 11:02:21.191600 8088866816 model_lib_v2.py:705] Step 1300 per-step time 0.950s
# INFO:tensorflow:{'Loss/classification_loss': 0.14396203,
#  'Loss/localization_loss': 0.09509777,
#  'Loss/regularization_loss': 0.1934754,
#  'Loss/total_loss': 0.4325352,
#  'learning_rate': 0.56666553}
# I0307 11:02:21.192374 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.14396203,
#  'Loss/localization_loss': 0.09509777,
#  'Loss/regularization_loss': 0.1934754,
#  'Loss/total_loss': 0.4325352,
#  'learning_rate': 0.56666553}
# INFO:tensorflow:Step 1400 per-step time 0.946s
# I0307 11:03:55.768068 8088866816 model_lib_v2.py:705] Step 1400 per-step time 0.946s
# INFO:tensorflow:{'Loss/classification_loss': 0.2859118,
#  'Loss/localization_loss': 0.123991445,
#  'Loss/regularization_loss': 0.20093095,
#  'Loss/total_loss': 0.6108342,
#  'learning_rate': 0.599999}
# I0307 11:03:55.768671 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.2859118,
#  'Loss/localization_loss': 0.123991445,
#  'Loss/regularization_loss': 0.20093095,
#  'Loss/total_loss': 0.6108342,
#  'learning_rate': 0.599999}
# INFO:tensorflow:Step 1500 per-step time 0.984s
# I0307 11:05:34.187978 8088866816 model_lib_v2.py:705] Step 1500 per-step time 0.984s
# INFO:tensorflow:{'Loss/classification_loss': 0.19502449,
#  'Loss/localization_loss': 0.092451185,
#  'Loss/regularization_loss': 0.20960164,
#  'Loss/total_loss': 0.49707732,
#  'learning_rate': 0.6333325}
# I0307 11:05:34.188724 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.19502449,
#  'Loss/localization_loss': 0.092451185,
#  'Loss/regularization_loss': 0.20960164,
#  'Loss/total_loss': 0.49707732,
#  'learning_rate': 0.6333325}
# INFO:tensorflow:Step 1600 per-step time 1.069s
# I0307 11:07:21.102651 8088866816 model_lib_v2.py:705] Step 1600 per-step time 1.069s
# INFO:tensorflow:{'Loss/classification_loss': 0.30178037,
#  'Loss/localization_loss': 0.1332237,
#  'Loss/regularization_loss': 0.21444684,
#  'Loss/total_loss': 0.6494509,
#  'learning_rate': 0.66666603}
# I0307 11:07:21.103575 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.30178037,
#  'Loss/localization_loss': 0.1332237,
#  'Loss/regularization_loss': 0.21444684,
#  'Loss/total_loss': 0.6494509,
#  'learning_rate': 0.66666603}
# INFO:tensorflow:Step 1700 per-step time 1.018s
# I0307 11:09:02.908549 8088866816 model_lib_v2.py:705] Step 1700 per-step time 1.018s
# INFO:tensorflow:{'Loss/classification_loss': 0.20457356,
#  'Loss/localization_loss': 0.10305864,
#  'Loss/regularization_loss': 0.2195813,
#  'Loss/total_loss': 0.5272135,
#  'learning_rate': 0.6999995}
# I0307 11:09:02.909250 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.20457356,
#  'Loss/localization_loss': 0.10305864,
#  'Loss/regularization_loss': 0.2195813,
#  'Loss/total_loss': 0.5272135,
#  'learning_rate': 0.6999995}
# INFO:tensorflow:Step 1800 per-step time 0.953s
# I0307 11:10:38.222548 8088866816 model_lib_v2.py:705] Step 1800 per-step time 0.953s
# INFO:tensorflow:{'Loss/classification_loss': 0.43334776,
#  'Loss/localization_loss': 0.18131088,
#  'Loss/regularization_loss': 0.23256546,
#  'Loss/total_loss': 0.8472241,
#  'learning_rate': 0.733333}
# I0307 11:10:38.223395 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.43334776,
#  'Loss/localization_loss': 0.18131088,
#  'Loss/regularization_loss': 0.23256546,
#  'Loss/total_loss': 0.8472241,
#  'learning_rate': 0.733333}
# INFO:tensorflow:Step 1900 per-step time 0.885s
# I0307 11:12:06.687356 8088866816 model_lib_v2.py:705] Step 1900 per-step time 0.885s
# INFO:tensorflow:{'Loss/classification_loss': 0.22605355,
#  'Loss/localization_loss': 0.11325912,
#  'Loss/regularization_loss': 0.26236072,
#  'Loss/total_loss': 0.60167336,
#  'learning_rate': 0.76666653}
# I0307 11:12:06.688267 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.22605355,
#  'Loss/localization_loss': 0.11325912,
#  'Loss/regularization_loss': 0.26236072,
#  'Loss/total_loss': 0.60167336,
#  'learning_rate': 0.76666653}
# INFO:tensorflow:Step 2000 per-step time 0.847s
# I0307 11:13:31.392045 8088866816 model_lib_v2.py:705] Step 2000 per-step time 0.847s
# INFO:tensorflow:{'Loss/classification_loss': 0.168533,
#  'Loss/localization_loss': 0.06210844,
#  'Loss/regularization_loss': 0.2639765,
#  'Loss/total_loss': 0.49461794,
#  'learning_rate': 0.8}
# I0307 11:13:31.392817 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.168533,
#  'Loss/localization_loss': 0.06210844,
#  'Loss/regularization_loss': 0.2639765,
#  'Loss/total_loss': 0.49461794,
#  'learning_rate': 0.8}
# INFO:tensorflow:Step 2100 per-step time 0.883s
# I0307 11:14:59.675098 8088866816 model_lib_v2.py:705] Step 2100 per-step time 0.883s
# INFO:tensorflow:{'Loss/classification_loss': 0.3456662,
#  'Loss/localization_loss': 0.1721574,
#  'Loss/regularization_loss': 0.26438993,
#  'Loss/total_loss': 0.7822135,
#  'learning_rate': 0.7996916}
# I0307 11:14:59.675899 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.3456662,
#  'Loss/localization_loss': 0.1721574,
#  'Loss/regularization_loss': 0.26438993,
#  'Loss/total_loss': 0.7822135,
#  'learning_rate': 0.7996916}
# INFO:tensorflow:Step 2200 per-step time 0.802s
# I0307 11:16:19.899828 8088866816 model_lib_v2.py:705] Step 2200 per-step time 0.802s
# INFO:tensorflow:{'Loss/classification_loss': 0.1342181,
#  'Loss/localization_loss': 0.07074464,
#  'Loss/regularization_loss': 0.26768127,
#  'Loss/total_loss': 0.472644,
#  'learning_rate': 0.7987669}
# I0307 11:16:19.900442 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.1342181,
#  'Loss/localization_loss': 0.07074464,
#  'Loss/regularization_loss': 0.26768127,
#  'Loss/total_loss': 0.472644,
#  'learning_rate': 0.7987669}
# INFO:tensorflow:Step 2300 per-step time 0.860s
# I0307 11:17:45.902522 8088866816 model_lib_v2.py:705] Step 2300 per-step time 0.860s
# INFO:tensorflow:{'Loss/classification_loss': 0.18511891,
#  'Loss/localization_loss': 0.057879757,
#  'Loss/regularization_loss': 0.26534668,
#  'Loss/total_loss': 0.50834537,
#  'learning_rate': 0.7972274}
# I0307 11:17:45.903348 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.18511891,
#  'Loss/localization_loss': 0.057879757,
#  'Loss/regularization_loss': 0.26534668,
#  'Loss/total_loss': 0.50834537,
#  'learning_rate': 0.7972274}
# INFO:tensorflow:Step 2400 per-step time 0.877s
# I0307 11:19:13.571601 8088866816 model_lib_v2.py:705] Step 2400 per-step time 0.877s
# INFO:tensorflow:{'Loss/classification_loss': 0.3074298,
#  'Loss/localization_loss': 0.13656789,
#  'Loss/regularization_loss': 0.2691143,
#  'Loss/total_loss': 0.713112,
#  'learning_rate': 0.79507536}
# I0307 11:19:13.572229 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.3074298,
#  'Loss/localization_loss': 0.13656789,
#  'Loss/regularization_loss': 0.2691143,
#  'Loss/total_loss': 0.713112,
#  'learning_rate': 0.79507536}
# INFO:tensorflow:Step 2500 per-step time 0.868s
# I0307 11:20:40.362906 8088866816 model_lib_v2.py:705] Step 2500 per-step time 0.868s
# INFO:tensorflow:{'Loss/classification_loss': 0.17209087,
#  'Loss/localization_loss': 0.0689885,
#  'Loss/regularization_loss': 0.26768425,
#  'Loss/total_loss': 0.5087636,
#  'learning_rate': 0.7923141}
# I0307 11:20:40.363632 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.17209087,
#  'Loss/localization_loss': 0.0689885,
#  'Loss/regularization_loss': 0.26768425,
#  'Loss/total_loss': 0.5087636,
#  'learning_rate': 0.7923141}
# INFO:tensorflow:Step 2600 per-step time 0.882s
# I0307 11:22:08.557048 8088866816 model_lib_v2.py:705] Step 2600 per-step time 0.882s
# INFO:tensorflow:{'Loss/classification_loss': 0.14651759,
#  'Loss/localization_loss': 0.06449358,
#  'Loss/regularization_loss': 0.26379475,
#  'Loss/total_loss': 0.47480592,
#  'learning_rate': 0.788948}
# I0307 11:22:08.557874 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.14651759,
#  'Loss/localization_loss': 0.06449358,
#  'Loss/regularization_loss': 0.26379475,
#  'Loss/total_loss': 0.47480592,
#  'learning_rate': 0.788948}
# INFO:tensorflow:Step 2700 per-step time 0.877s
# I0307 11:23:36.264154 8088866816 model_lib_v2.py:705] Step 2700 per-step time 0.877s
# INFO:tensorflow:{'Loss/classification_loss': 0.12673455,
#  'Loss/localization_loss': 0.061039634,
#  'Loss/regularization_loss': 0.25987366,
#  'Loss/total_loss': 0.44764784,
#  'learning_rate': 0.78498214}
# I0307 11:23:36.264856 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.12673455,
#  'Loss/localization_loss': 0.061039634,
#  'Loss/regularization_loss': 0.25987366,
#  'Loss/total_loss': 0.44764784,
#  'learning_rate': 0.78498214}
# INFO:tensorflow:Step 2800 per-step time 0.886s
# I0307 11:25:04.846421 8088866816 model_lib_v2.py:705] Step 2800 per-step time 0.886s
# INFO:tensorflow:{'Loss/classification_loss': 0.15669711,
#  'Loss/localization_loss': 0.064810164,
#  'Loss/regularization_loss': 0.25759503,
#  'Loss/total_loss': 0.4791023,
#  'learning_rate': 0.7804226}
# I0307 11:25:04.847187 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.15669711,
#  'Loss/localization_loss': 0.064810164,
#  'Loss/regularization_loss': 0.25759503,
#  'Loss/total_loss': 0.4791023,
#  'learning_rate': 0.7804226}
# INFO:tensorflow:Step 2900 per-step time 0.865s
# I0307 11:26:31.316848 8088866816 model_lib_v2.py:705] Step 2900 per-step time 0.865s
# INFO:tensorflow:{'Loss/classification_loss': 0.23817663,
#  'Loss/localization_loss': 0.102694914,
#  'Loss/regularization_loss': 0.2589692,
#  'Loss/total_loss': 0.59984076,
#  'learning_rate': 0.7752766}
# I0307 11:26:31.317557 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.23817663,
#  'Loss/localization_loss': 0.102694914,
#  'Loss/regularization_loss': 0.2589692,
#  'Loss/total_loss': 0.59984076,
#  'learning_rate': 0.7752766}
# INFO:tensorflow:Step 3000 per-step time 0.885s
# I0307 11:27:59.860553 8088866816 model_lib_v2.py:705] Step 3000 per-step time 0.885s
# INFO:tensorflow:{'Loss/classification_loss': 0.17472143,
#  'Loss/localization_loss': 0.08717466,
#  'Loss/regularization_loss': 0.2589807,
#  'Loss/total_loss': 0.52087677,
#  'learning_rate': 0.7695518}
# I0307 11:27:59.861345 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.17472143,
#  'Loss/localization_loss': 0.08717466,
#  'Loss/regularization_loss': 0.2589807,
#  'Loss/total_loss': 0.52087677,
#  'learning_rate': 0.7695518}
# INFO:tensorflow:Step 3100 per-step time 0.818s
# I0307 11:29:21.688953 8088866816 model_lib_v2.py:705] Step 3100 per-step time 0.818s
# INFO:tensorflow:{'Loss/classification_loss': 0.1572611,
#  'Loss/localization_loss': 0.07309068,
#  'Loss/regularization_loss': 0.25404653,
#  'Loss/total_loss': 0.4843983,
#  'learning_rate': 0.76325727}
# I0307 11:29:21.689687 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.1572611,
#  'Loss/localization_loss': 0.07309068,
#  'Loss/regularization_loss': 0.25404653,
#  'Loss/total_loss': 0.4843983,
#  'learning_rate': 0.76325727}
# INFO:tensorflow:Step 3200 per-step time 0.793s
# I0307 11:30:40.967963 8088866816 model_lib_v2.py:705] Step 3200 per-step time 0.793s
# INFO:tensorflow:{'Loss/classification_loss': 0.16319847,
#  'Loss/localization_loss': 0.078981206,
#  'Loss/regularization_loss': 0.2566565,
#  'Loss/total_loss': 0.49883616,
#  'learning_rate': 0.7564026}
# I0307 11:30:40.968593 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.16319847,
#  'Loss/localization_loss': 0.078981206,
#  'Loss/regularization_loss': 0.2566565,
#  'Loss/total_loss': 0.49883616,
#  'learning_rate': 0.7564026}
# INFO:tensorflow:Step 3300 per-step time 0.798s
# I0307 11:32:00.781328 8088866816 model_lib_v2.py:705] Step 3300 per-step time 0.798s
# INFO:tensorflow:{'Loss/classification_loss': 0.17919953,
#  'Loss/localization_loss': 0.11314634,
#  'Loss/regularization_loss': 0.2554447,
#  'Loss/total_loss': 0.5477906,
#  'learning_rate': 0.7489984}
# I0307 11:32:00.781979 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.17919953,
#  'Loss/localization_loss': 0.11314634,
#  'Loss/regularization_loss': 0.2554447,
#  'Loss/total_loss': 0.5477906,
#  'learning_rate': 0.7489984}
# INFO:tensorflow:Step 3400 per-step time 0.794s
# I0307 11:33:20.219829 8088866816 model_lib_v2.py:705] Step 3400 per-step time 0.794s
# INFO:tensorflow:{'Loss/classification_loss': 0.17889886,
#  'Loss/localization_loss': 0.095122494,
#  'Loss/regularization_loss': 0.2691974,
#  'Loss/total_loss': 0.54321873,
#  'learning_rate': 0.7410561}
# I0307 11:33:20.220490 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.17889886,
#  'Loss/localization_loss': 0.095122494,
#  'Loss/regularization_loss': 0.2691974,
#  'Loss/total_loss': 0.54321873,
#  'learning_rate': 0.7410561}
# INFO:tensorflow:Step 3500 per-step time 0.804s
# I0307 11:34:40.585335 8088866816 model_lib_v2.py:705] Step 3500 per-step time 0.804s
# INFO:tensorflow:{'Loss/classification_loss': 0.14723651,
#  'Loss/localization_loss': 0.051469646,
#  'Loss/regularization_loss': 0.26444513,
#  'Loss/total_loss': 0.46315128,
#  'learning_rate': 0.7325878}
# I0307 11:34:40.586032 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.14723651,
#  'Loss/localization_loss': 0.051469646,
#  'Loss/regularization_loss': 0.26444513,
#  'Loss/total_loss': 0.46315128,
#  'learning_rate': 0.7325878}
# INFO:tensorflow:Step 3600 per-step time 0.801s
# I0307 11:36:00.697582 8088866816 model_lib_v2.py:705] Step 3600 per-step time 0.801s
# INFO:tensorflow:{'Loss/classification_loss': 0.11906733,
#  'Loss/localization_loss': 0.054964606,
#  'Loss/regularization_loss': 0.25721604,
#  'Loss/total_loss': 0.43124798,
#  'learning_rate': 0.72360677}
# I0307 11:36:00.698260 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.11906733,
#  'Loss/localization_loss': 0.054964606,
#  'Loss/regularization_loss': 0.25721604,
#  'Loss/total_loss': 0.43124798,
#  'learning_rate': 0.72360677}
# INFO:tensorflow:Step 3700 per-step time 0.799s
# I0307 11:37:20.584463 8088866816 model_lib_v2.py:705] Step 3700 per-step time 0.799s
# INFO:tensorflow:{'Loss/classification_loss': 0.11516482,
#  'Loss/localization_loss': 0.04622558,
#  'Loss/regularization_loss': 0.25169238,
#  'Loss/total_loss': 0.41308278,
#  'learning_rate': 0.71412677}
# I0307 11:37:20.585231 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.11516482,
#  'Loss/localization_loss': 0.04622558,
#  'Loss/regularization_loss': 0.25169238,
#  'Loss/total_loss': 0.41308278,
#  'learning_rate': 0.71412677}
# INFO:tensorflow:Step 3800 per-step time 0.859s
# I0307 11:38:46.526130 8088866816 model_lib_v2.py:705] Step 3800 per-step time 0.859s
# INFO:tensorflow:{'Loss/classification_loss': 0.112730436,
#  'Loss/localization_loss': 0.046665043,
#  'Loss/regularization_loss': 0.24694164,
#  'Loss/total_loss': 0.40633714,
#  'learning_rate': 0.7041624}
# I0307 11:38:46.526845 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.112730436,
#  'Loss/localization_loss': 0.046665043,
#  'Loss/regularization_loss': 0.24694164,
#  'Loss/total_loss': 0.40633714,
#  'learning_rate': 0.7041624}
# INFO:tensorflow:Step 3900 per-step time 0.785s
# I0307 11:40:05.003610 8088866816 model_lib_v2.py:705] Step 3900 per-step time 0.785s
# INFO:tensorflow:{'Loss/classification_loss': 0.19594881,
#  'Loss/localization_loss': 0.07997368,
#  'Loss/regularization_loss': 0.2454191,
#  'Loss/total_loss': 0.52134156,
#  'learning_rate': 0.69372904}
# I0307 11:40:05.004287 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.19594881,
#  'Loss/localization_loss': 0.07997368,
#  'Loss/regularization_loss': 0.2454191,
#  'Loss/total_loss': 0.52134156,
#  'learning_rate': 0.69372904}
# INFO:tensorflow:Step 4000 per-step time 0.793s
# I0307 11:41:24.335056 8088866816 model_lib_v2.py:705] Step 4000 per-step time 0.793s
# INFO:tensorflow:{'Loss/classification_loss': 0.16284248,
#  'Loss/localization_loss': 0.080489814,
#  'Loss/regularization_loss': 0.24502085,
#  'Loss/total_loss': 0.48835313,
#  'learning_rate': 0.68284273}
# I0307 11:41:24.335707 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.16284248,
#  'Loss/localization_loss': 0.080489814,
#  'Loss/regularization_loss': 0.24502085,
#  'Loss/total_loss': 0.48835313,
#  'learning_rate': 0.68284273}
# INFO:tensorflow:Step 4100 per-step time 0.790s
# I0307 11:42:43.308917 8088866816 model_lib_v2.py:705] Step 4100 per-step time 0.790s
# INFO:tensorflow:{'Loss/classification_loss': 0.11985361,
#  'Loss/localization_loss': 0.037427094,
#  'Loss/regularization_loss': 0.24031208,
#  'Loss/total_loss': 0.39759278,
#  'learning_rate': 0.6715203}
# I0307 11:42:43.309703 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.11985361,
#  'Loss/localization_loss': 0.037427094,
#  'Loss/regularization_loss': 0.24031208,
#  'Loss/total_loss': 0.39759278,
#  'learning_rate': 0.6715203}
# INFO:tensorflow:Step 4200 per-step time 0.787s
# I0307 11:44:02.041914 8088866816 model_lib_v2.py:705] Step 4200 per-step time 0.787s
# INFO:tensorflow:{'Loss/classification_loss': 0.08840648,
#  'Loss/localization_loss': 0.036565576,
#  'Loss/regularization_loss': 0.23423877,
#  'Loss/total_loss': 0.35921085,
#  'learning_rate': 0.65977925}
# I0307 11:44:02.042561 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.08840648,
#  'Loss/localization_loss': 0.036565576,
#  'Loss/regularization_loss': 0.23423877,
#  'Loss/total_loss': 0.35921085,
#  'learning_rate': 0.65977925}
# INFO:tensorflow:Step 4300 per-step time 0.775s
# I0307 11:45:19.580223 8088866816 model_lib_v2.py:705] Step 4300 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.11961023,
#  'Loss/localization_loss': 0.0657262,
#  'Loss/regularization_loss': 0.22884665,
#  'Loss/total_loss': 0.41418308,
#  'learning_rate': 0.64763755}
# I0307 11:45:19.580863 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.11961023,
#  'Loss/localization_loss': 0.0657262,
#  'Loss/regularization_loss': 0.22884665,
#  'Loss/total_loss': 0.41418308,
#  'learning_rate': 0.64763755}
# INFO:tensorflow:Step 4400 per-step time 0.778s
# I0307 11:46:37.343282 8088866816 model_lib_v2.py:705] Step 4400 per-step time 0.778s
# INFO:tensorflow:{'Loss/classification_loss': 0.12089193,
#  'Loss/localization_loss': 0.044913504,
#  'Loss/regularization_loss': 0.22485766,
#  'Loss/total_loss': 0.3906631,
#  'learning_rate': 0.63511413}
# I0307 11:46:37.343966 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.12089193,
#  'Loss/localization_loss': 0.044913504,
#  'Loss/regularization_loss': 0.22485766,
#  'Loss/total_loss': 0.3906631,
#  'learning_rate': 0.63511413}
# INFO:tensorflow:Step 4500 per-step time 0.783s
# I0307 11:47:55.600556 8088866816 model_lib_v2.py:705] Step 4500 per-step time 0.783s
# INFO:tensorflow:{'Loss/classification_loss': 0.12097326,
#  'Loss/localization_loss': 0.04981419,
#  'Loss/regularization_loss': 0.22076279,
#  'Loss/total_loss': 0.39155024,
#  'learning_rate': 0.6222281}
# I0307 11:47:55.601233 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.12097326,
#  'Loss/localization_loss': 0.04981419,
#  'Loss/regularization_loss': 0.22076279,
#  'Loss/total_loss': 0.39155024,
#  'learning_rate': 0.6222281}
# INFO:tensorflow:Step 4600 per-step time 0.787s
# I0307 11:49:14.319148 8088866816 model_lib_v2.py:705] Step 4600 per-step time 0.787s
# INFO:tensorflow:{'Loss/classification_loss': 0.114921734,
#  'Loss/localization_loss': 0.053966377,
#  'Loss/regularization_loss': 0.22017998,
#  'Loss/total_loss': 0.38906807,
#  'learning_rate': 0.60899943}
# I0307 11:49:14.319790 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.114921734,
#  'Loss/localization_loss': 0.053966377,
#  'Loss/regularization_loss': 0.22017998,
#  'Loss/total_loss': 0.38906807,
#  'learning_rate': 0.60899943}
# INFO:tensorflow:Step 4700 per-step time 0.785s
# I0307 11:50:32.867907 8088866816 model_lib_v2.py:705] Step 4700 per-step time 0.785s
# INFO:tensorflow:{'Loss/classification_loss': 0.13722222,
#  'Loss/localization_loss': 0.058853462,
#  'Loss/regularization_loss': 0.21985132,
#  'Loss/total_loss': 0.415927,
#  'learning_rate': 0.5954485}
# I0307 11:50:32.868545 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.13722222,
#  'Loss/localization_loss': 0.058853462,
#  'Loss/regularization_loss': 0.21985132,
#  'Loss/total_loss': 0.415927,
#  'learning_rate': 0.5954485}
# INFO:tensorflow:Step 4800 per-step time 0.789s
# I0307 11:51:51.739258 8088866816 model_lib_v2.py:705] Step 4800 per-step time 0.789s
# INFO:tensorflow:{'Loss/classification_loss': 0.09485575,
#  'Loss/localization_loss': 0.04717789,
#  'Loss/regularization_loss': 0.21599405,
#  'Loss/total_loss': 0.3580277,
#  'learning_rate': 0.5815962}
# I0307 11:51:51.739914 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.09485575,
#  'Loss/localization_loss': 0.04717789,
#  'Loss/regularization_loss': 0.21599405,
#  'Loss/total_loss': 0.3580277,
#  'learning_rate': 0.5815962}
# INFO:tensorflow:Step 4900 per-step time 0.786s
# I0307 11:53:10.370182 8088866816 model_lib_v2.py:705] Step 4900 per-step time 0.786s
# INFO:tensorflow:{'Loss/classification_loss': 0.09545364,
#  'Loss/localization_loss': 0.058872573,
#  'Loss/regularization_loss': 0.21300906,
#  'Loss/total_loss': 0.36733526,
#  'learning_rate': 0.5674639}
# I0307 11:53:10.370834 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.09545364,
#  'Loss/localization_loss': 0.058872573,
#  'Loss/regularization_loss': 0.21300906,
#  'Loss/total_loss': 0.36733526,
#  'learning_rate': 0.5674639}
# INFO:tensorflow:Step 5000 per-step time 0.777s
# I0307 11:54:28.023919 8088866816 model_lib_v2.py:705] Step 5000 per-step time 0.777s
# INFO:tensorflow:{'Loss/classification_loss': 0.07235441,
#  'Loss/localization_loss': 0.038796984,
#  'Loss/regularization_loss': 0.2093669,
#  'Loss/total_loss': 0.3205183,
#  'learning_rate': 0.55307335}
# I0307 11:54:28.024470 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.07235441,
#  'Loss/localization_loss': 0.038796984,
#  'Loss/regularization_loss': 0.2093669,
#  'Loss/total_loss': 0.3205183,
#  'learning_rate': 0.55307335}
# INFO:tensorflow:Step 5100 per-step time 0.806s
# I0307 11:55:48.635807 8088866816 model_lib_v2.py:705] Step 5100 per-step time 0.806s
# INFO:tensorflow:{'Loss/classification_loss': 0.10970058,
#  'Loss/localization_loss': 0.048639283,
#  'Loss/regularization_loss': 0.20533088,
#  'Loss/total_loss': 0.36367074,
#  'learning_rate': 0.53844684}
# I0307 11:55:48.636475 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.10970058,
#  'Loss/localization_loss': 0.048639283,
#  'Loss/regularization_loss': 0.20533088,
#  'Loss/total_loss': 0.36367074,
#  'learning_rate': 0.53844684}
# INFO:tensorflow:Step 5200 per-step time 0.785s
# I0307 11:57:07.143770 8088866816 model_lib_v2.py:705] Step 5200 per-step time 0.785s
# INFO:tensorflow:{'Loss/classification_loss': 0.10943681,
#  'Loss/localization_loss': 0.032442987,
#  'Loss/regularization_loss': 0.20063138,
#  'Loss/total_loss': 0.34251118,
#  'learning_rate': 0.5236068}
# I0307 11:57:07.144421 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.10943681,
#  'Loss/localization_loss': 0.032442987,
#  'Loss/regularization_loss': 0.20063138,
#  'Loss/total_loss': 0.34251118,
#  'learning_rate': 0.5236068}
# INFO:tensorflow:Step 5300 per-step time 0.780s
# I0307 11:58:25.138966 8088866816 model_lib_v2.py:705] Step 5300 per-step time 0.780s
# INFO:tensorflow:{'Loss/classification_loss': 0.07033418,
#  'Loss/localization_loss': 0.10291076,
#  'Loss/regularization_loss': 0.19594888,
#  'Loss/total_loss': 0.36919382,
#  'learning_rate': 0.50857615}
# I0307 11:58:25.139661 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.07033418,
#  'Loss/localization_loss': 0.10291076,
#  'Loss/regularization_loss': 0.19594888,
#  'Loss/total_loss': 0.36919382,
#  'learning_rate': 0.50857615}
# INFO:tensorflow:Step 5400 per-step time 0.784s
# I0307 11:59:43.554131 8088866816 model_lib_v2.py:705] Step 5400 per-step time 0.784s
# INFO:tensorflow:{'Loss/classification_loss': 0.091497764,
#  'Loss/localization_loss': 0.036847193,
#  'Loss/regularization_loss': 0.19279718,
#  'Loss/total_loss': 0.32114214,
#  'learning_rate': 0.49337816}
# I0307 11:59:43.554840 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.091497764,
#  'Loss/localization_loss': 0.036847193,
#  'Loss/regularization_loss': 0.19279718,
#  'Loss/total_loss': 0.32114214,
#  'learning_rate': 0.49337816}
# INFO:tensorflow:Step 5500 per-step time 0.782s
# I0307 12:01:01.783488 8088866816 model_lib_v2.py:705] Step 5500 per-step time 0.782s
# INFO:tensorflow:{'Loss/classification_loss': 0.10878957,
#  'Loss/localization_loss': 0.045276854,
#  'Loss/regularization_loss': 0.1900814,
#  'Loss/total_loss': 0.34414783,
#  'learning_rate': 0.47803614}
# I0307 12:01:01.784137 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.10878957,
#  'Loss/localization_loss': 0.045276854,
#  'Loss/regularization_loss': 0.1900814,
#  'Loss/total_loss': 0.34414783,
#  'learning_rate': 0.47803614}
# INFO:tensorflow:Step 5600 per-step time 0.780s
# I0307 12:02:19.804133 8088866816 model_lib_v2.py:705] Step 5600 per-step time 0.780s
# INFO:tensorflow:{'Loss/classification_loss': 0.14539695,
#  'Loss/localization_loss': 0.05747937,
#  'Loss/regularization_loss': 0.18673477,
#  'Loss/total_loss': 0.38961107,
#  'learning_rate': 0.46257383}
# I0307 12:02:19.804778 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.14539695,
#  'Loss/localization_loss': 0.05747937,
#  'Loss/regularization_loss': 0.18673477,
#  'Loss/total_loss': 0.38961107,
#  'learning_rate': 0.46257383}
# INFO:tensorflow:Step 5700 per-step time 0.786s
# I0307 12:03:38.402091 8088866816 model_lib_v2.py:705] Step 5700 per-step time 0.786s
# INFO:tensorflow:{'Loss/classification_loss': 0.15245429,
#  'Loss/localization_loss': 0.058718443,
#  'Loss/regularization_loss': 0.18417898,
#  'Loss/total_loss': 0.3953517,
#  'learning_rate': 0.4470149}
# I0307 12:03:38.402800 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.15245429,
#  'Loss/localization_loss': 0.058718443,
#  'Loss/regularization_loss': 0.18417898,
#  'Loss/total_loss': 0.3953517,
#  'learning_rate': 0.4470149}
# INFO:tensorflow:Step 5800 per-step time 0.780s
# I0307 12:04:56.388743 8088866816 model_lib_v2.py:705] Step 5800 per-step time 0.780s
# INFO:tensorflow:{'Loss/classification_loss': 0.09222343,
#  'Loss/localization_loss': 0.0443588,
#  'Loss/regularization_loss': 0.18206787,
#  'Loss/total_loss': 0.3186501,
#  'learning_rate': 0.4313836}
# I0307 12:04:56.389417 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.09222343,
#  'Loss/localization_loss': 0.0443588,
#  'Loss/regularization_loss': 0.18206787,
#  'Loss/total_loss': 0.3186501,
#  'learning_rate': 0.4313836}
# INFO:tensorflow:Step 5900 per-step time 0.788s
# I0307 12:06:15.158640 8088866816 model_lib_v2.py:705] Step 5900 per-step time 0.788s
# INFO:tensorflow:{'Loss/classification_loss': 0.17982164,
#  'Loss/localization_loss': 0.07312616,
#  'Loss/regularization_loss': 0.18006869,
#  'Loss/total_loss': 0.43301648,
#  'learning_rate': 0.41570392}
# I0307 12:06:15.159317 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.17982164,
#  'Loss/localization_loss': 0.07312616,
#  'Loss/regularization_loss': 0.18006869,
#  'Loss/total_loss': 0.43301648,
#  'learning_rate': 0.41570392}
# INFO:tensorflow:Step 6000 per-step time 0.778s
# I0307 12:07:32.957592 8088866816 model_lib_v2.py:705] Step 6000 per-step time 0.778s
# INFO:tensorflow:{'Loss/classification_loss': 0.08039108,
#  'Loss/localization_loss': 0.04031451,
#  'Loss/regularization_loss': 0.17639716,
#  'Loss/total_loss': 0.29710275,
#  'learning_rate': 0.39999998}
# I0307 12:07:32.958220 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.08039108,
#  'Loss/localization_loss': 0.04031451,
# ...
# INFO:tensorflow:Step 7300 per-step time 0.821s
# I0307 12:25:04.404133 8088866816 model_lib_v2.py:705] Step 7300 per-step time 0.821s
# INFO:tensorflow:{'Loss/classification_loss': 0.06278665,
#  'Loss/localization_loss': 0.02286122,
#  'Loss/regularization_loss': 0.14564194,
#  'Loss/total_loss': 0.2312898,
#  'learning_rate': 0.20455146}
# I0307 12:25:04.404815 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.06278665,
#  'Loss/localization_loss': 0.02286122,
#  'Loss/regularization_loss': 0.14564194,
#  'Loss/total_loss': 0.2312898,
#  'learning_rate': 0.20455146}
# INFO:tensorflow:Step 7400 per-step time 0.811s
# I0307 12:26:25.521770 8088866816 model_lib_v2.py:705] Step 7400 per-step time 0.811s
# INFO:tensorflow:{'Loss/classification_loss': 0.052476652,
#  'Loss/localization_loss': 0.016479978,
#  'Loss/regularization_loss': 0.14423516,
#  'Loss/total_loss': 0.21319179,
#  'learning_rate': 0.19100054}
# I0307 12:26:25.522481 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.052476652,
#  'Loss/localization_loss': 0.016479978,
#  'Loss/regularization_loss': 0.14423516,
#  'Loss/total_loss': 0.21319179,
#  'learning_rate': 0.19100054}
# INFO:tensorflow:Step 7500 per-step time 0.805s
# I0307 12:27:46.043877 8088866816 model_lib_v2.py:705] Step 7500 per-step time 0.805s
# INFO:tensorflow:{'Loss/classification_loss': 0.051215593,
#  'Loss/localization_loss': 0.018067364,
#  'Loss/regularization_loss': 0.1426977,
#  'Loss/total_loss': 0.21198067,
#  'learning_rate': 0.17777193}
# I0307 12:27:46.044550 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.051215593,
#  'Loss/localization_loss': 0.018067364,
#  'Loss/regularization_loss': 0.1426977,
#  'Loss/total_loss': 0.21198067,
#  'learning_rate': 0.17777193}
# INFO:tensorflow:Step 7600 per-step time 0.802s
# I0307 12:29:06.240485 8088866816 model_lib_v2.py:705] Step 7600 per-step time 0.802s
# INFO:tensorflow:{'Loss/classification_loss': 0.06012625,
#  'Loss/localization_loss': 0.018663855,
#  'Loss/regularization_loss': 0.14113532,
#  'Loss/total_loss': 0.21992543,
#  'learning_rate': 0.16488583}
# I0307 12:29:06.241144 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.06012625,
#  'Loss/localization_loss': 0.018663855,
#  'Loss/regularization_loss': 0.14113532,
#  'Loss/total_loss': 0.21992543,
#  'learning_rate': 0.16488583}
# INFO:tensorflow:Step 7700 per-step time 0.799s
# I0307 12:30:26.175384 8088866816 model_lib_v2.py:705] Step 7700 per-step time 0.799s
# INFO:tensorflow:{'Loss/classification_loss': 0.08754857,
#  'Loss/localization_loss': 0.0158361,
#  'Loss/regularization_loss': 0.13983817,
#  'Loss/total_loss': 0.24322283,
#  'learning_rate': 0.15236245}
# I0307 12:30:26.176061 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.08754857,
#  'Loss/localization_loss': 0.0158361,
#  'Loss/regularization_loss': 0.13983817,
#  'Loss/total_loss': 0.24322283,
#  'learning_rate': 0.15236245}
# INFO:tensorflow:Step 7800 per-step time 0.800s
# I0307 12:31:46.161282 8088866816 model_lib_v2.py:705] Step 7800 per-step time 0.800s
# INFO:tensorflow:{'Loss/classification_loss': 0.035509143,
#  'Loss/localization_loss': 0.013145227,
#  'Loss/regularization_loss': 0.13854165,
#  'Loss/total_loss': 0.18719602,
#  'learning_rate': 0.14022072}
# I0307 12:31:46.162010 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.035509143,
#  'Loss/localization_loss': 0.013145227,
#  'Loss/regularization_loss': 0.13854165,
#  'Loss/total_loss': 0.18719602,
#  'learning_rate': 0.14022072}
# INFO:tensorflow:Step 7900 per-step time 0.796s
# I0307 12:33:05.805740 8088866816 model_lib_v2.py:705] Step 7900 per-step time 0.796s
# INFO:tensorflow:{'Loss/classification_loss': 0.062290937,
#  'Loss/localization_loss': 0.012339958,
#  'Loss/regularization_loss': 0.13730828,
#  'Loss/total_loss': 0.21193919,
#  'learning_rate': 0.12847972}
# I0307 12:33:05.806398 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.062290937,
#  'Loss/localization_loss': 0.012339958,
#  'Loss/regularization_loss': 0.13730828,
#  'Loss/total_loss': 0.21193919,
#  'learning_rate': 0.12847972}
# INFO:tensorflow:Step 8000 per-step time 0.809s
# I0307 12:34:26.746753 8088866816 model_lib_v2.py:705] Step 8000 per-step time 0.809s
# INFO:tensorflow:{'Loss/classification_loss': 0.040342946,
#  'Loss/localization_loss': 0.012408964,
#  'Loss/regularization_loss': 0.13618177,
#  'Loss/total_loss': 0.18893369,
#  'learning_rate': 0.117157295}
# I0307 12:34:26.748162 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.040342946,
#  'Loss/localization_loss': 0.012408964,
#  'Loss/regularization_loss': 0.13618177,
#  'Loss/total_loss': 0.18893369,
#  'learning_rate': 0.117157295}
# INFO:tensorflow:Step 8100 per-step time 0.819s
# I0307 12:35:48.638405 8088866816 model_lib_v2.py:705] Step 8100 per-step time 0.819s
# INFO:tensorflow:{'Loss/classification_loss': 0.044267382,
#  'Loss/localization_loss': 0.020589111,
#  'Loss/regularization_loss': 0.13514014,
#  'Loss/total_loss': 0.19999662,
#  'learning_rate': 0.106271006}
# I0307 12:35:48.639168 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.044267382,
#  'Loss/localization_loss': 0.020589111,
#  'Loss/regularization_loss': 0.13514014,
#  'Loss/total_loss': 0.19999662,
#  'learning_rate': 0.106271006}
# INFO:tensorflow:Step 8200 per-step time 0.908s
# I0307 12:37:19.487735 8088866816 model_lib_v2.py:705] Step 8200 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.050447818,
#  'Loss/localization_loss': 0.012745727,
#  'Loss/regularization_loss': 0.13419814,
#  'Loss/total_loss': 0.19739169,
#  'learning_rate': 0.095837615}
# I0307 12:37:19.488546 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.050447818,
#  'Loss/localization_loss': 0.012745727,
#  'Loss/regularization_loss': 0.13419814,
#  'Loss/total_loss': 0.19739169,
#  'learning_rate': 0.095837615}
# INFO:tensorflow:Step 8300 per-step time 0.829s
# I0307 12:38:42.348684 8088866816 model_lib_v2.py:705] Step 8300 per-step time 0.829s
# INFO:tensorflow:{'Loss/classification_loss': 0.05616419,
#  'Loss/localization_loss': 0.022316083,
#  'Loss/regularization_loss': 0.1333455,
#  'Loss/total_loss': 0.21182577,
#  'learning_rate': 0.08587315}
# I0307 12:38:42.349349 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.05616419,
#  'Loss/localization_loss': 0.022316083,
#  'Loss/regularization_loss': 0.1333455,
#  'Loss/total_loss': 0.21182577,
#  'learning_rate': 0.08587315}
# INFO:tensorflow:Step 8400 per-step time 0.802s
# I0307 12:40:02.526939 8088866816 model_lib_v2.py:705] Step 8400 per-step time 0.802s
# INFO:tensorflow:{'Loss/classification_loss': 0.053020556,
#  'Loss/localization_loss': 0.012572695,
#  'Loss/regularization_loss': 0.13257465,
#  'Loss/total_loss': 0.19816789,
#  'learning_rate': 0.0763932}
# I0307 12:40:02.528196 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.053020556,
#  'Loss/localization_loss': 0.012572695,
#  'Loss/regularization_loss': 0.13257465,
#  'Loss/total_loss': 0.19816789,
#  'learning_rate': 0.0763932}
# INFO:tensorflow:Step 8500 per-step time 0.809s
# I0307 12:41:23.411130 8088866816 model_lib_v2.py:705] Step 8500 per-step time 0.809s
# INFO:tensorflow:{'Loss/classification_loss': 0.10027955,
#  'Loss/localization_loss': 0.035508692,
#  'Loss/regularization_loss': 0.13191347,
#  'Loss/total_loss': 0.2677017,
#  'learning_rate': 0.06741214}
# I0307 12:41:23.411845 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.10027955,
#  'Loss/localization_loss': 0.035508692,
#  'Loss/regularization_loss': 0.13191347,
#  'Loss/total_loss': 0.2677017,
#  'learning_rate': 0.06741214}
# INFO:tensorflow:Step 8600 per-step time 0.829s
# I0307 12:42:46.303752 8088866816 model_lib_v2.py:705] Step 8600 per-step time 0.829s
# INFO:tensorflow:{'Loss/classification_loss': 0.0667031,
#  'Loss/localization_loss': 0.012021832,
#  'Loss/regularization_loss': 0.13131061,
#  'Loss/total_loss': 0.21003555,
#  'learning_rate': 0.058943916}
# I0307 12:42:46.304442 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.0667031,
#  'Loss/localization_loss': 0.012021832,
#  'Loss/regularization_loss': 0.13131061,
#  'Loss/total_loss': 0.21003555,
#  'learning_rate': 0.058943916}
# INFO:tensorflow:Step 8700 per-step time 0.881s
# I0307 12:44:14.392930 8088866816 model_lib_v2.py:705] Step 8700 per-step time 0.881s
# INFO:tensorflow:{'Loss/classification_loss': 0.036472797,
#  'Loss/localization_loss': 0.012879819,
#  'Loss/regularization_loss': 0.13078253,
#  'Loss/total_loss': 0.18013515,
#  'learning_rate': 0.051001575}
# I0307 12:44:14.393682 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.036472797,
#  'Loss/localization_loss': 0.012879819,
#  'Loss/regularization_loss': 0.13078253,
#  'Loss/total_loss': 0.18013515,
#  'learning_rate': 0.051001575}
# INFO:tensorflow:Step 8800 per-step time 0.841s
# I0307 12:45:38.546267 8088866816 model_lib_v2.py:705] Step 8800 per-step time 0.841s
# INFO:tensorflow:{'Loss/classification_loss': 0.04139405,
#  'Loss/localization_loss': 0.009125993,
#  'Loss/regularization_loss': 0.1303202,
#  'Loss/total_loss': 0.18084025,
#  'learning_rate': 0.04359741}
# I0307 12:45:38.546983 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.04139405,
#  'Loss/localization_loss': 0.009125993,
#  'Loss/regularization_loss': 0.1303202,
#  'Loss/total_loss': 0.18084025,
#  'learning_rate': 0.04359741}
# INFO:tensorflow:Step 8900 per-step time 0.833s
# I0307 12:47:01.817245 8088866816 model_lib_v2.py:705] Step 8900 per-step time 0.833s
# INFO:tensorflow:{'Loss/classification_loss': 0.041610308,
#  'Loss/localization_loss': 0.016044596,
#  'Loss/regularization_loss': 0.12992543,
#  'Loss/total_loss': 0.18758033,
#  'learning_rate': 0.036742713}
# I0307 12:47:01.817984 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.041610308,
#  'Loss/localization_loss': 0.016044596,
#  'Loss/regularization_loss': 0.12992543,
#  'Loss/total_loss': 0.18758033,
#  'learning_rate': 0.036742713}
# INFO:tensorflow:Step 9000 per-step time 0.839s
# I0307 12:48:25.746769 8088866816 model_lib_v2.py:705] Step 9000 per-step time 0.839s
# INFO:tensorflow:{'Loss/classification_loss': 0.032451462,
#  'Loss/localization_loss': 0.008758888,
#  'Loss/regularization_loss': 0.12958926,
#  'Loss/total_loss': 0.17079961,
#  'learning_rate': 0.030448198}
# I0307 12:48:25.747512 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.032451462,
#  'Loss/localization_loss': 0.008758888,
#  'Loss/regularization_loss': 0.12958926,
#  'Loss/total_loss': 0.17079961,
#  'learning_rate': 0.030448198}
# INFO:tensorflow:Step 9100 per-step time 0.837s
# I0307 12:49:49.455630 8088866816 model_lib_v2.py:705] Step 9100 per-step time 0.837s
# INFO:tensorflow:{'Loss/classification_loss': 0.03392408,
#  'Loss/localization_loss': 0.009893791,
#  'Loss/regularization_loss': 0.12931865,
#  'Loss/total_loss': 0.17313653,
#  'learning_rate': 0.024723435}
# I0307 12:49:49.456351 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.03392408,
#  'Loss/localization_loss': 0.009893791,
#  'Loss/regularization_loss': 0.12931865,
#  'Loss/total_loss': 0.17313653,
#  'learning_rate': 0.024723435}
# INFO:tensorflow:Step 9200 per-step time 0.806s
# I0307 12:51:10.022634 8088866816 model_lib_v2.py:705] Step 9200 per-step time 0.806s
# INFO:tensorflow:{'Loss/classification_loss': 0.067435816,
#  'Loss/localization_loss': 0.016990684,
#  'Loss/regularization_loss': 0.12909488,
#  'Loss/total_loss': 0.21352139,
#  'learning_rate': 0.019577408}
# I0307 12:51:10.023326 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.067435816,
#  'Loss/localization_loss': 0.016990684,
#  'Loss/regularization_loss': 0.12909488,
#  'Loss/total_loss': 0.21352139,
#  'learning_rate': 0.019577408}
# INFO:tensorflow:Step 9300 per-step time 0.810s
# I0307 12:52:31.012389 8088866816 model_lib_v2.py:705] Step 9300 per-step time 0.810s
# INFO:tensorflow:{'Loss/classification_loss': 0.06469198,
#  'Loss/localization_loss': 0.023493802,
#  'Loss/regularization_loss': 0.12892076,
#  'Loss/total_loss': 0.21710655,
#  'learning_rate': 0.015017915}
# I0307 12:52:31.012994 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.06469198,
#  'Loss/localization_loss': 0.023493802,
#  'Loss/regularization_loss': 0.12892076,
#  'Loss/total_loss': 0.21710655,
#  'learning_rate': 0.015017915}
# INFO:tensorflow:Step 9400 per-step time 0.821s
# I0307 12:53:53.074635 8088866816 model_lib_v2.py:705] Step 9400 per-step time 0.821s
# INFO:tensorflow:{'Loss/classification_loss': 0.055161208,
#  'Loss/localization_loss': 0.013665856,
#  'Loss/regularization_loss': 0.1287879,
#  'Loss/total_loss': 0.19761497,
#  'learning_rate': 0.011052012}
# I0307 12:53:53.075386 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.055161208,
#  'Loss/localization_loss': 0.013665856,
#  'Loss/regularization_loss': 0.1287879,
#  'Loss/total_loss': 0.19761497,
#  'learning_rate': 0.011052012}
# INFO:tensorflow:Step 9500 per-step time 0.841s
# I0307 12:55:17.127754 8088866816 model_lib_v2.py:705] Step 9500 per-step time 0.841s
# INFO:tensorflow:{'Loss/classification_loss': 0.054399066,
#  'Loss/localization_loss': 0.023348885,
#  'Loss/regularization_loss': 0.12869212,
#  'Loss/total_loss': 0.20644006,
#  'learning_rate': 0.007685876}
# I0307 12:55:17.128443 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.054399066,
#  'Loss/localization_loss': 0.023348885,
#  'Loss/regularization_loss': 0.12869212,
#  'Loss/total_loss': 0.20644006,
#  'learning_rate': 0.007685876}
# INFO:tensorflow:Step 9600 per-step time 0.849s
# I0307 12:56:42.061342 8088866816 model_lib_v2.py:705] Step 9600 per-step time 0.849s
# INFO:tensorflow:{'Loss/classification_loss': 0.02583827,
#  'Loss/localization_loss': 0.010510183,
#  'Loss/regularization_loss': 0.1286269,
#  'Loss/total_loss': 0.16497535,
#  'learning_rate': 0.004924655}
# I0307 12:56:42.062041 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.02583827,
#  'Loss/localization_loss': 0.010510183,
#  'Loss/regularization_loss': 0.1286269,
#  'Loss/total_loss': 0.16497535,
#  'learning_rate': 0.004924655}
# INFO:tensorflow:Step 9700 per-step time 0.911s
# I0307 12:58:13.166833 8088866816 model_lib_v2.py:705] Step 9700 per-step time 0.911s
# INFO:tensorflow:{'Loss/classification_loss': 0.051039163,
#  'Loss/localization_loss': 0.011987475,
#  'Loss/regularization_loss': 0.12858652,
#  'Loss/total_loss': 0.19161315,
#  'learning_rate': 0.0027726174}
# I0307 12:58:13.167519 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.051039163,
#  'Loss/localization_loss': 0.011987475,
#  'Loss/regularization_loss': 0.12858652,
#  'Loss/total_loss': 0.19161315,
#  'learning_rate': 0.0027726174}
# INFO:tensorflow:Step 9800 per-step time 0.881s
# I0307 12:59:41.227589 8088866816 model_lib_v2.py:705] Step 9800 per-step time 0.881s
# INFO:tensorflow:{'Loss/classification_loss': 0.04286162,
#  'Loss/localization_loss': 0.009201675,
#  'Loss/regularization_loss': 0.12856537,
#  'Loss/total_loss': 0.18062867,
#  'learning_rate': 0.0012330533}
# I0307 12:59:41.228291 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.04286162,
#  'Loss/localization_loss': 0.009201675,
#  'Loss/regularization_loss': 0.12856537,
#  'Loss/total_loss': 0.18062867,
#  'learning_rate': 0.0012330533}
# INFO:tensorflow:Step 9900 per-step time 0.908s
# I0307 13:01:12.046453 8088866816 model_lib_v2.py:705] Step 9900 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.04410901,
#  'Loss/localization_loss': 0.01544056,
#  'Loss/regularization_loss': 0.1285573,
#  'Loss/total_loss': 0.18810686,
#  'learning_rate': 0.00030839443}
# I0307 13:01:12.047140 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.04410901,
#  'Loss/localization_loss': 0.01544056,
#  'Loss/regularization_loss': 0.1285573,
#  'Loss/total_loss': 0.18810686,
#  'learning_rate': 0.00030839443}
# INFO:tensorflow:Step 10000 per-step time 0.887s
# I0307 13:02:40.731366 8088866816 model_lib_v2.py:705] Step 10000 per-step time 0.887s
# INFO:tensorflow:{'Loss/classification_loss': 0.05908948,
#  'Loss/localization_loss': 0.022452023,
#  'Loss/regularization_loss': 0.12855591,
#  'Loss/total_loss': 0.21009742,
#  'learning_rate': 0.0}
# I0307 13:02:40.732043 8088866816 model_lib_v2.py:708] {'Loss/classification_loss': 0.05908948,
#  'Loss/localization_loss': 0.022452023,
#  'Loss/regularization_loss': 0.12855591,
#  'Loss/total_loss': 0.21009742,
#  'learning_rate': 0.0}

# %% [markdown]
# # Export the model for inference

# %%
# Copy exporting script to scripts folder
if linux or mac:
    # !cp {os.path.join('TensorFlow','models', 'research', 'object_detection', 'exporter_main_v2.py')} {paths['scripts_path']}
else:
    # !copy {os.path.join('TensorFlow','models', 'research', 'object_detection', 'exporter_main_v2.py')} {paths['scripts_path']}

exporting_script = os.path.join(paths['scripts_path'], 'exporter_main_v2.py')
exporting_command = "python {} --input_type image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(exporting_script, files['pipeline_config'], paths['checkpoint_path'], paths['output_path'])

print(exporting_script)
print("Run the following in a new terminal: " + exporting_command)
# Out:
# Tensorflow/scripts/exporter_main_v2.py
# Run the following in a new terminal: python Tensorflow/scripts/exporter_main_v2.py --input_type image_tensor --pipeline_config_path=Tensorflow/workspace/models/hummifier_model/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/hummifier_model --output_directory=Tensorflow/workspace/models/hummifier_model/export

# %%
# !{exporting_command}
# Out:
# 2024-03-07 13:07:50.404451: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2024-03-07 13:07:50.404480: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-03-07 13:07:50.404486: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-03-07 13:07:50.404524: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-07 13:07:50.404538: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0307 13:07:50.482511 8088866816 deprecation.py:641] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0307 13:07:52.635329 8088866816 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:07:53.388046 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:07:53.388165 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:07:53.388250 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:07:53.388287 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:07:53.388319 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:07:53.388351 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# I0307 13:07:56.308858 8088866816 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0307 13:07:57.556169 8088866816 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to boxpredictor_convolutionalclasshead_5_classpredictor_biasadd_readvariableop_resource in the SavedModel.
# I0307 13:07:57.927864 8088866816 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x29662a320>, because it is not built.
# W0307 13:07:58.684416 8088866816 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x29662a320>, because it is not built.
# I0307 13:08:03.726744 8088866816 save.py:274] Found untraced functions such as BoxPredictor_layer_call_fn, BoxPredictor_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 122). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/hummifier_model/export/saved_model/assets
# I0307 13:08:06.577029 8088866816 builder_impl.py:804] Assets written to: Tensorflow/workspace/models/hummifier_model/export/saved_model/assets
# I0307 13:08:06.624729 8088866816 fingerprinting_utils.py:48] Writing fingerprint to Tensorflow/workspace/models/hummifier_model/export/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/hummifier_model/export/pipeline.config
# I0307 13:08:06.730010 8088866816 config_util.py:253] Writing pipeline config file to Tensorflow/workspace/models/hummifier_model/export/pipeline.config

# %% [markdown]
# # Evaluate the model

# %%
eval_script = os.path.join(paths['api_path'], 'research', 'object_detection', 'model_main_tf2.py')
eval_command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(eval_script, paths['checkpoint_path'], files['pipeline_config'], paths['checkpoint_path'])

print(eval_script)
print("Run the following in a new terminal: " + eval_command)
# Out:
# Tensorflow/models/research/object_detection/model_main_tf2.py
# Run the following in a new terminal: python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/hummifier_model --pipeline_config_path=Tensorflow/workspace/models/hummifier_model/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/hummifier_model

# %%
# !{eval_command}
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0307 13:04:10.439249 8088866816 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0307 13:04:10.439342 8088866816 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0307 13:04:10.439368 8088866816 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0307 13:04:10.439396 8088866816 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0307 13:04:10.439423 8088866816 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2024-03-07 13:04:10.442172: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2024-03-07 13:04:10.442204: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-03-07 13:04:10.442208: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-03-07 13:04:10.442391: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-07 13:04:10.442410: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# I0307 13:04:10.477264 8088866816 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# I0307 13:04:10.477753 8088866816 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0307 13:04:10.477797 8088866816 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0307 13:04:10.477819 8088866816 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0307 13:04:10.479962 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0307 13:04:10.491837 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/object_detection-0.1-py3.10.egg/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0307 13:04:12.232048 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0307 13:04:12.702513 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/hummifier_model
# I0307 13:04:13.715085 8088866816 checkpoint_utils.py:168] Waiting for new checkpoint at Tensorflow/workspace/models/hummifier_model
# INFO:tensorflow:Found new checkpoint at Tensorflow/workspace/models/hummifier_model/ckpt-11
# I0307 13:04:13.715481 8088866816 checkpoint_utils.py:177] Found new checkpoint at Tensorflow/workspace/models/hummifier_model/ckpt-11
# /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0307 13:04:16.361488 8088866816 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:04:17.020728 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:04:17.020860 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:04:17.020903 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:04:17.020937 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:04:17.020969 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0307 13:04:17.020998 8088866816 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# I0307 13:04:20.929925 8088866816 api.py:460] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# 2024-03-07 13:04:21.874412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0307 13:04:23.557665 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0307 13:04:23.640311 8088866816 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0307 13:04:23.718413 8088866816 deprecation.py:364] From /Users/eseidel/Documents/Projects/hummifier_v2/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 16 images.
# I0307 13:04:33.100474 8088866816 coco_evaluation.py:293] Performing evaluation on 16 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0307 13:04:33.100645 8088866816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0307 13:04:33.101112 8088866816 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.839
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.725
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.869
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.875
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.705
# INFO:tensorflow:Eval metrics at step 10000
# I0307 13:04:33.158490 8088866816 model_lib_v2.py:1015] Eval metrics at step 10000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.680971
# I0307 13:04:33.167165 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.680971
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.838590
# I0307 13:04:33.170132 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.838590
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.724734
# I0307 13:04:33.172034 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.724734
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0307 13:04:33.173995 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.869059
# I0307 13:04:33.176357 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.869059
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.617369
# I0307 13:04:33.178505 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.617369
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.705000
# I0307 13:04:33.180511 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.705000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.730000
# I0307 13:04:33.182371 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.730000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.730000
# I0307 13:04:33.183848 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.730000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0307 13:04:33.184951 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.875000
# I0307 13:04:33.187184 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.875000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.705000
# I0307 13:04:33.188774 8088866816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.705000
# INFO:tensorflow:	+ Loss/localization_loss: 0.185111
# I0307 13:04:33.190638 8088866816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.185111
# INFO:tensorflow:	+ Loss/classification_loss: 0.861391
# I0307 13:04:33.192543 8088866816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.861391
# INFO:tensorflow:	+ Loss/regularization_loss: 0.128556
# I0307 13:04:33.194144 8088866816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.128556
# INFO:tensorflow:	+ Loss/total_loss: 1.175058
# I0307 13:04:33.195677 8088866816 model_lib_v2.py:1018] 	+ Loss/total_loss: 1.175058
# INFO:tensorflow:Exiting evaluation at step 10000
# I0307 13:04:33.328643 8088866816 model_lib_v2.py:1168] Exiting evaluation at step 10000
